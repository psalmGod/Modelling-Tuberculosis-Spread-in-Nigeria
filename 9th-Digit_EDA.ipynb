# %%
import pandas as pd 
import numpy as np
import pandas_profiling as pp
import seaborn as sp
import matplotlib.pyplot as plt

# %%
tb_data=pd.read_excel("tbdataset.xlsx")
sci_data=pd.read_csv("9digit.db.csv")

# %%
tb_data=pd.DataFrame(tb_data)
sci_data=pd.DataFrame(sci_data)
sci_data=sci_data.sort_values(by=["State"],ascending=True)
sci_data=sci_data.set_index(["_loc","fr_loc"])
sci_data
# Out:
#               scale_sci                       State   TB_cases  \
# _loc  fr_loc
# NGA25 NGA15       79563   Federal Capital Territory  1,405,201
#       NGA37       26627               Zamfara State  3,278,873
#       NGA1        70325                  Abia State  2,845,370
#       NGA2        35556               Adamawa State  3,178,950
#       NGA3        73552             Akwa Ibom State  3,902,051
#       NGA4        93175               Anambra State  4,177,828
#       NGA5        23882                Bauchi State  4,653,066
#       NGA6        75495               Bayelsa State  1,704,515
#       NGA7        82023                 Benue State  4,253,641
#       NGA8        27141                 Borno State  2,176,947
#       NGA9       105546           Cross River State  2,882,988
#       NGA10       74244                 Delta State  4,112,455
#       NGA11      104352                Ebonyi State  2,176,947
#       NGA12       66390                   Edo State  3,233,366
# ...

# %%
profile=pp.ProfileReport(sci_data)
profile.to_file("9th_digit.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
y=sci_data["Rel_TB"]
x=sci_data["scale_sci"]
from math import sqrt
from scipy.stats import boxcox

# %%
sp.regplot(x="scale_sci",y="Rel_TB",data=sci_data)
plt.show()

# %%
sp.distplot(boxcox(y,1.5),kde=True)
# Out:
# C:\Users\SAMSON\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sp.distplot(boxcox(y,0.5),kde=True)
# Out:
# C:\Users\SAMSON\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sp.distplot((y),kde=True)
# Out:
# C:\Users\SAMSON\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rel_TB', ylabel='Density'>

# %%
sp.distplot(boxcox(x,0.5),kde=True)
# Out:
# C:\Users\SAMSON\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sp.distplot(boxcox(x,0),kde=True)
# Out:
# C:\Users\SAMSON\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sp.distplot(boxcox(x,1.5),kde=True)
# Out:
# C:\Users\SAMSON\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sp.distplot(boxcox(y,1),kde=True)
# Out:
# C:\Users\SAMSON\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
import statsmodels.api as sm
y=sci_data["Rel_TB"]
x=sci_data[["scale_sci","Rel_Population"]]
y=np.array(y)
x=np.array(x)
model=sm.OLS(y,x)
fit=model.fit()
result=fit.summary()
result
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.642
# Model:                            OLS   Adj. R-squared (uncentered):              0.622
# Method:                 Least Squares   F-statistic:                              31.39
# Date:                Wed, 25 May 2022   Prob (F-statistic):                    1.56e-08
# Time:                        09:59:07   Log-Likelihood:                         -67.672
# No. Observations:                  37   AIC:                                      139.3
# Df Residuals:                      35   BIC:                                      142.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
y=sci_data["Rel_TB"]
x=(sci_data[["scale_sci","Rel_Population","TB_case_2019"]])

y=boxcox(y,0)
y=np.array(y)
x=np.array(x)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
model=sm.OLS(y_train,x_train)
fit=model.fit()
result=fit.summary()
result
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.718
# Model:                            OLS   Adj. R-squared (uncentered):              0.685
# Method:                 Least Squares   F-statistic:                              22.07
# Date:                Wed, 25 May 2022   Prob (F-statistic):                    2.56e-07
# Time:                        10:44:41   Log-Likelihood:                         -16.096
# No. Observations:                  29   AIC:                                      38.19
# Df Residuals:                      26   BIC:                                      42.29
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
predictions=fit.predict(x_train)
predictions
x_train=pd.DataFrame(x_train)
x_train[1]
ac_pred=pd.DataFrame(y_train,predictions)
ac_pred
# Out:
#                   0
#  0.795784  1.065822
#  0.593830  0.000000
#  0.478286  0.209350
#  0.352846  0.492476
#  0.545199  0.510826
# -0.589900 -0.382992
#  0.587972  0.862224
#  0.152300  0.587787
#  0.153091  0.209350
#  0.631803  0.916291
#  0.522807  0.786238
#  0.777112  1.203973
#  1.385598  2.302585
#  1.290318  0.836248
#  0.245226  0.587787
#  0.357433  0.649662
#  1.123543  0.888892
#  0.433321 -0.105361
#  1.227457  1.241713
# -0.023191  0.356675
#  0.745073  1.132514
#  0.258644  0.340927
#  0.226507  0.810930
# -0.436966 -0.032790
#  0.031601  0.587787
#  0.781823  0.786238
# -0.002932 -0.279314
#  0.187785  0.251314
#  1.106385  0.011173

# %%
y_pred=pd.DataFrame(predictions)
sns.kdeplot(y_train-predictions)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Residual plot

# %%
# importing critical libraries
import pandas            as pd
import matplotlib.pyplot as plt
import seaborn           as sns
import numpy as np


# importing model types
from sklearn.linear_model import Ridge# linear models for you to enjoy
from sklearn.neighbors import KNeighborsRegressor
from statsmodels.regression.rolling import RollingOLS
# importing ML tools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler # standardizing data
from sklearn.svm import LinearSVC

# %%
x=pd.DataFrame(x).corr()

# %%
y=sci_data["Rel_TB"]
x=sci_data["scale_sci"]
y=boxcox(y,0)
scaler=StandardScaler()
x_scale=scaler.fit_transform(x_train)

# %%
model_=Ridge()

# %%
model_.fit(x_scale,y_train)
# Out:
# Ridge()

# %%
model_.score(x_scale,y_train)
# Out:
# 0.3027044361438621

# %%
from sklearn.metrics import r2_score

predictions=model_.predict(x_test)
predictions
data=pd.DataFrame(x_test,y_test)

# %%
sns.kdeplot(y_train)
sns.kdeplot(predictions)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Comparing actual and predicted distributions

# %%
predictions=fit.predict(x_train)
plt.scatter(x,y)
plt.scatter(x_train[1],predictions)

# %%
predictions=fit.predict(x_test)
predictions
x_test=pd.DataFrame(x_test)
x_test[1]
ac_pred=pd.DataFrame(y_test,predictions)
ac_pred
# Out:
#                   0
#  0.259267  0.439367
# -0.333617  0.280302
#  0.526771  0.474458
#  0.537696  0.251314
#  0.430301  0.130362
#  0.936560  0.439367
#  0.757162  1.034074
#  0.378650  0.607989

# %%
sns.kdeplot(y_test)
sns.kdeplot(predictions)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Out:
# True

# %%
sci_data.index=np.arange(1,len(sci_data)+1)
sci_data_1=sci_data[["TB_cases","Rel_Population","Rel_TB","scale_sci"]]
sci_data_1[["spread_rate","population_density_1","population_density_2","SCI"]]=sci_data_1
work=sci_data_1.drop(["TB_cases","Rel_Population","Rel_TB","scale_sci"],axis=1)
work
# Out:
# C:\Users\SAMSON\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#    spread_rate  population_density_1  population_density_2     SCI
# 1    1,405,201              6.485624              1.011236   79563
# 2    3,278,873              2.779493              1.914894   26627
# 3    2,845,370              3.202960              2.903226   70325
# 4    3,178,950              2.866860              1.285714   35556
# 5    3,902,051              2.335594              1.406250   73552
# 6    4,177,828              2.181422              2.195122   93175
# 7    4,653,066              1.958624              1.428571   23882
# ...

# %%
# Out:
#     scale_sci   TB_cases  Rel_Population  TB_case_2019     Rel_TB  \
# 1       79563  1,405,201        6.485624            89   1.011236
# 2       26627  3,278,873        2.779493            47   1.914894
# 3       70325  2,845,370        3.202960            31   2.903226
# 4       35556  3,178,950        2.866860            70   1.285714
# 5       73552  3,902,051        2.335594            64   1.406250
# 6       93175  4,177,828        2.181422            41   2.195122
# 7       23882  4,653,066        1.958624            63   1.428571
# 8       75495  1,704,515        5.346744            39   2.307692
# 9       82023  4,253,641        2.142542            73   1.232877
# 10      27141  2,176,947        4.186416            41   2.195122
# 11     105546  2,882,988        3.161166            70   1.285714
# 12      74244  4,112,455        2.216098            49   1.836735
# 13     104352  2,176,947        4.186416            37   2.432432
# ...
